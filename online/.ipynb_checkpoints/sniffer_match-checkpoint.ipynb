# %%
# Convert lines of frame to Python dictionaries
def sniffer_log_to_dict(sniffer_log: "List[Str]") -> "List[Dict]":
    ret_dicts = []
    last_timestamp = 0
    overflow_counts = 0
    for l in sniffer_log:
        ret_dict = {}
        this_timestamp = int(l[:10])/1e6
        if last_timestamp > this_timestamp:
            # Overflow, add 2**32
            overflow_counts += 1
        last_timestamp = this_timestamp
        this_timestamp += 2**32/1e6*overflow_counts
        ret_dict["timestamp"] = this_timestamp
        ret_dict["channel"] = int(l[13:15])
        ret_dict["rssi"] = int(l[18:21])
        ret_dict["frame_type"] = l[22:24]
        ret_dict["ds_flag"] = l[25:27]
        ret_dict["dest_mac"] = l[28:40]
        ret_dict["src_mac"] = l[41:53]
        ret_dicts += [ret_dict]
    return ret_dicts

# %%
sp435 = sniffer_log_to_dict(open("../SNIFFER435.LOG").readlines())
sp436 = sniffer_log_to_dict(open("../SNIFFER436.LOG").readlines())
sp437 = sniffer_log_to_dict(open("../SNIFFER437.LOG").readlines())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-188f016c5890> in <module>()
#       1 sp435 = sniffer_log_to_dict(open("../SNIFFER435.LOG").readlines())
# ----> 2 sp436 = sniffer_log_to_dict(open("../SNIFFER436.LOG").read|lines())
#       3 sp437 = sniffer_log_to_dict(open("../SNIFFER437.LOG").readlines())
#
# NameError: name 'lines' is not defined

# %%
sp4 = sp5 = sp6 = []
with open("serport4.log") as f:
    sp4 = f.readlines()
with open("serport5.log") as f:
    sp5 = f.readlines()
with open("serport6.log") as f:
    sp6 = f.readlines()
len(sp4)
# Out:
# 4442

# %%
sp4[10][14:24]
# Out:
# '3191588599'

# %%
def filter_valid_lines(in_list):
    out_list = []
    for l in in_list:
        if len(l) != 25:
            # Wrong length
            continue
        if l[0] != "R" and l[0] != "N":
            # Wrong header
            continue
        out_item = {}
        try:
            int(l[1:13],16)
            int(l[14:24],10)
        except ValueError:
            # Wrong format
            continue
        out_item["new"] = l[0] == 'N'
        out_item["mac"] = l[1:13]
        out_item["time"] = l[14:24]
        out_list += [out_item]
    return out_list

# %%
sp4 = filter_valid_lines(sp4)
sp5 = filter_valid_lines(sp5)
sp6 = filter_valid_lines(sp6)

# %%
len(set(s["mac"] for s in sp6) & set(s["mac"] for s in sp5))
# Out:
# 336

# %%
# Out:
# 5

# %%
len(set(s["mac"] for s in sp5))
# Out:
# 1564

# %%
def floaten_time(in_list):
    for l in in_list:
        l["time"] = int(l["time"])/1e6

# %%
def unwrap_time(in_list):
    if type(in_list[0]["time"]) == float:
        assert False, "Already unwrapped"
    last_ts = int(in_list[0]["time"])
    cur_ts_add = 0
    for l in in_list:
        now_ts = int(l["time"])
        if now_ts < 2000000000:
            # Wrapped
            cur_ts_add = (1<<32)/1e6
        else:
            cur_ts_add = 0
        l["time"] = now_ts/1e6+cur_ts_add

# %%
floaten_time(sp4)
floaten_time(sp5)
unwrap_time(sp6)

# %%
def relativize_time(in_list):
    start_ts = in_list[0]["time"]
    for l in in_list:
        l["time"] -= start_ts

# %%
relativize_time(sp4)
relativize_time(sp5)
relativize_time(sp6)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# color key, map mac address bottom 2 digits to colors
int(sp5[0]["mac"][-2:],16)/256
# Out:
# 0.0

# %%
# Find most common mac address and match based on it?
from collections import Counter
common_macs = set(s["mac"] for s in sp4) & set(s["mac"] for s in sp6) & set(s["mac"] for s in sp6)
mac_cnt = Counter([s["mac"] for s in sp4 if s["mac"] in common_macs]+[s["mac"] for s in sp6 if s["mac"] in common_macs]+[s["mac"] for s in sp5 if s["mac"] in common_macs])

# %%
mac_cnt.most_common()
# Out:
# [('0095691eaf22', 283),
#  ('a03be3089361', 143),
#  ('98e79a51579c', 116),
#  ('3096fbdba555', 113),
#  ('b83765c52a9f', 98),
#  ('041b6da2f70a', 95),
#  ('6c72e70c5001', 91),
#  ('8866a59236eb', 89),
#  ('7c01914ff945', 87),
#  ('000fc3000b00', 74),
#  ('1a4c101fffff', 64),
#  ('38378b220f90', 63),
#  ('000000000b00', 62),
#  ('c8e0eb40bad5', 55),
#  ('cc3a61b906df', 53),
#  ('b8634d699535', 52),
#  ('c0a53e7403c8', 49),
#  ('b0481a70f329', 47),
#  ('38a4ed4d7391', 46),
#  ('00aefa50a503', 46),
#  ('446d57e835b4', 45),
#  ('c0174da95ead', 45),
#  ('a03be30514ec', 43),
#  ('010fc3000b00', 42),
#  ('8866a5df5b4a', 42),
#  ('145f942956a7', 38),
#  ('c0174da96cb5', 35),
#  ('1c36bbc45d50', 34),
#  ('c0a53e0ff5f3', 34),
#  ('149d09096d0e', 32),
#  ('884477fab8fa', 32),
#  ('4c49e3f99a15', 30),
#  ('203cae8b82ac', 29),
#  ('dc415fd255f0', 29),
#  ('7423448d1118', 28),
#  ('dc3714749446', 28),
#  ('9801a76ae955', 28),
#  ('c83c85ad8899', 27),
#  ('1aec1103ffff', 27),
#  ('608334f2d21d', 26),
#  ('a03be3afa1ce', 26),
#  ('2cf0a2d34853', 26),
#  ('484b20010d24', 24),
#  ('000fc3000100', 23),
#  ('dca9041be7ee', 23),
#  ('742344f0ab83', 23),
#  ('b81daab0a8b6', 22),
#  ('948bc10aa02c', 22),
#  ('90b68677b790', 22),
#  ('842e27f6cd6e', 22),
#  ('202d071d840c', 22),
#  ('b0e2352875b0', 22),
#  ('d0fccc263a60', 21),
#  ('68ef432c116f', 21),
#  ('24181d9db4b0', 21),
#  ('a45e60a9d96e', 19),
#  ('daa119018598', 19),
#  ('9476b7d9edd1', 19),
#  ('e0c767ad991f', 19),
#  ('e458b8ded0c3', 19),
#  ('6cab319c72bd', 19),
#  ('d0fccc6f16fe', 19),
#  ('e0a3ac54e0d8', 18),
#  ('f86214d06091', 18),
#  ('a03be3a6c284', 17),
#  ('dcefca06491b', 17),
#  ('0000e2000b00', 17),
#  ('b8634d54be72', 17),
#  ('c0a53e302c06', 17),
#  ('c4618bb12fd4', 17),
#  ('00000c2d1aac', 17),
#  ('223b9163c763', 17),
#  ('e02cb20b56e2', 17),
#  ('a408ea823961', 17),
#  ('1c91485bd155', 17),
#  ('508f4cd66f9b', 17),
#  ('94d0291036ff', 16),
#  ('b4527dbed1a2', 16),
#  ('708bcd2a1837', 16),
#  ('1ecf0614e060', 16),
#  ('b08900c336fe', 15),
#  ('2c200bbe463b', 15),
#  ('60d9c780d8ec', 15),
#  ('70ef00ae5f1f', 15),
#  ('989e63c50d14', 15),
#  ('54724fca9cbe', 15),
#  ('a03be349e865', 15),
#  ('0cd7463ddffc', 14),
#  ('bca920cb17e6', 14),
#  ('94652da41683', 14),
#  ('dccf96b798d2', 14),
#  ('4c3275dbe780', 13),
#  ('18f643b21c02', 13),
#  ('3efdf4abfb36', 13),
#  ('acc1eed2b5cc', 13),
#  ('daa1197c90c1', 13),
#  ('202d07c89a32', 13),
#  ('6083347485b2', 13),
#  ('6e82f51e1a93', 13),
#  ('0000e7010000', 13),
#  ('ecd09f36a036', 13),
#  ('7a2c88513d93', 13),
#  ('7c0191900012', 12),
#  ('a408eaadb54e', 12),
#  ('000740000100', 12),
#  ('5848228d2453', 12),
#  ('1c232c1ed085', 12),
#  ('d4909c4808db', 12),
#  ('9288d15e9a34', 12),
#  ('c4438fc0a0ee', 12),
#  ('daa1197f27d5', 11),
#  ('e49adc6d82a1', 11),
#  ('0e09d8057521', 11),
#  ('c49ded046a72', 11),
#  ('2884fabe2ded', 11),
#  ('7451ba78f694', 11),
#  ('76d13ce0c072', 11),
#  ('485a3f162454', 11),
#  ('030fc3000b00', 11),
#  ('1e84767e9c34', 11),
#  ('acbc32c604a3', 11),
#  ('5caf0688e41c', 11),
#  ('e05f45726137', 11),
#  ('000740000600', 10),
#  ('a0cc2b8b558c', 10),
#  ('4a4ee32244f3', 10),
#  ('f25ac03317d6', 10),
#  ('dcefca35eda6', 10),
#  ('380b400fd239', 10),
#  ('dc74a8941c9c', 10),
#  ('f209b6f568ee', 10),
#  ('dccf96d08771', 10),
#  ('a8667fdbadfa', 10),
#  ('f45c89b1b3bb', 10),
#  ('b2bb0c9336fa', 10),
#  ('426e9823eaba', 10),
#  ('14dda9a77bf9', 10),
#  ('60a4d0986b00', 10),
#  ('ca3f297f2e62', 10),
#  ('b8d7af691fd6', 10),
#  ('50f0d3c64a77', 10),
#  ('000000000600', 9),
#  ('daa119aefa8f', 9),
#  ('b0c559abd7a1', 9),
#  ('daa119806d39', 9),
#  ('c6416445333c', 9),
#  ('daa119753723', 9),
#  ('d2331e8835d5', 9),
#  ('a6681e0cc60b', 9),
#  ('daa119e7fc17', 9),
#  ('202d07c89180', 9),
#  ('b019c68605cc', 9),
#  ('d022be90fd20', 9),
#  ('5433cb3d13aa', 9),
#  ('88add2d428c8', 9),
#  ('6c72e736ea0d', 9),
#  ('7802f87e995f', 9),
#  ('7e2d3a1bba8c', 9),
#  ('58482271ae4a', 9),
#  ('5433cbb0970a', 9),
#  ('daa1196b13cf', 9),
#  ('2c598a492526', 9),
#  ('203caeb26c07', 9),
#  ('e4e4ab5fe027', 9),
#  ('720668946d21', 9),
#  ('daa119705e10', 9),
#  ('dcefcab2ee5f', 9),
#  ('c894bbf811a6', 8),
#  ('02bc4937be28', 8),
#  ('daa119f66c70', 8),
#  ('224cb0762db8', 8),
#  ('da45f95574b6', 8),
#  ('b4f7a17900fd', 8),
#  ('2ed012e12504', 8),
#  ('daa119444276', 8),
#  ('daa119a67a7c', 8),
#  ('daa11941b124', 8),
#  ('f6f75a6bd247', 8),
#  ('daa119c05ce9', 8),
#  ('6665c40d6be0', 8),
#  ('fafdecd138fd', 8),
#  ('daa1192ca0d5', 8),
#  ('84c7ea7a8281', 8),
#  ('60a4d0b2755e', 8),
#  ('b4bff669e9f7', 8),
#  ('c894bbe46cf3', 8),
#  ('daa1198b47c3', 8),
#  ('e49adcdf4d95', 8),
#  ('70ef00d14761', 8),
#  ('3408bce454b3', 8),
#  ('26ed1b726575', 8),
#  ('a03be3d2b811', 8),
#  ('04b167b38540', 8),
#  ('88797eeaa10d', 8),
#  ('88797ec4e05b', 8),
#  ('4400109a7c73', 8),
#  ('daa119604c86', 8),
#  ('b8c11109ffc3', 8),
#  ('cc29f5dab5ac', 8),
#  ('c0eefbf06f0a', 8),
#  ('4a6564519312', 8),
#  ('dca4ca0795e1', 8),
#  ('10417fa5169b', 8),
#  ('5433cb4a87b9', 8),
#  ('ee7f2c7ebc57', 8),
#  ('a0d795298bab', 8),
#  ('7081ebeec988', 8),
#  ('ea6d8074560e', 8),
#  ('02fda1fb8de9', 8),
#  ('dad215ce620f', 8),
#  ('a2e1f6c2e2d3', 8),
#  ('a2536859409f', 8),
#  ('ca4a086de10f', 7),
#  ('18659017ee2f', 7),
#  ('daa119b9fa29', 7),
#  ('9a6cd2ac2dd1', 7),
#  ('8c85901617cd', 7),
#  ('d4619da77022', 7),
#  ('aa760a7e7f68', 7),
#  ('daa11946923e', 7),
#  ('3ee51dcc49b1', 7),
#  ('008740000600', 7),
#  ('2d1aac0903ff', 7),
#  ('daa119c07738', 7),
#  ('a4e9752bbdc5', 7),
#  ('404e36601a7e', 7),
#  ('daa119310ab8', 7),
#  ('88329bc9968c', 7),
#  ('9a8f2dcd2b01', 7),
#  ('8cf5a38bb44c', 7),
#  ('e49adc804c52', 7),
#  ('161f95b0294f', 7),
#  ('daa119ccf5ca', 7),
#  ('000100000000', 7),
#  ('d013fd255548', 7),
#  ('1a1ddfd89bad', 7),
#  ('daa119ce128f', 7),
#  ('daa119cbb8ee', 7),
#  ('ee4e7e1cb0e7', 7),
#  ('daa1194f64c5', 7),
#  ('9a4a7b865947', 7),
#  ('daa119962e7f', 7),
#  ('baec2faff3ea', 7),
#  ('5a59baaa75b8', 7),
#  ('76bd8f9cbffe', 7),
#  ('5e219b75ece9', 7),
#  ('742344f1d297', 7),
#  ('ea3842c8dcd4', 7),
#  ('423b67d828ee', 7),
#  ('5a5a59ed179c', 7),
#  ('8c8ef297f2c5', 7),
#  ('126b195477a0', 7),
#  ('867ac5ef3655', 7),
#  ('c222cfc0b417', 7),
#  ('92830925988a', 7),
#  ('42d37ad1eeac', 7),
#  ('daa11960869a', 6),
#  ('cae97049dcb2', 6),
#  ('f431c378aae2', 6),
#  ('68dbca03b564', 6),
#  ('daa11930af75', 6),
#  ('5848228bc3e9', 6),
#  ('fa4c063abdaa', 6),
#  ('9ce33f587340', 6),
#  ('daa119279f1d', 6),
#  ('aeae7ba2336f', 6),
#  ('daa119116c21', 6),
#  ('daa119895521', 6),
#  ('daa119fe2f05', 6),
#  ('a6870e9535a9', 6),
#  ('261e88087ebb', 6),
#  ('54f20102664c', 6),
#  ('b67f9391c4fc', 6),
#  ('aa89906d0fc2', 6),
#  ('96117e9275d3', 6),
#  ('460571100000', 6),
#  ('4040a74b0cff', 6),
#  ('567a00eb3693', 6),
#  ('daa11976b697', 6),
#  ('daa119b207c4', 6),
#  ('daa119bbb9fc', 6),
#  ('484b49010d17', 6),
#  ('a652b9ac0007', 6),
#  ('9ce33f66fee3', 6),
#  ('a8667f7c4288', 6),
#  ('b251f7f57858', 6),
#  ('daa11974e3e3', 6),
#  ('020fc3000600', 6),
#  ('daa119bb1834', 6),
#  ('daa119026ce5', 6),
#  ('a644ab55254c', 6),
#  ('76cc2646bada', 6),
#  ('daa11910daa7', 6),
#  ('8cf5a31b0a77', 6),
#  ('1ea53288928e', 6),
#  ('daa119186e71', 6),
#  ('daa119057543', 6),
#  ('daa11939d887', 6),
#  ('a6baef113c0c', 6),
#  ('8e5500edee07', 6),
#  ('2acd27f50b51', 6),
#  ('42c1fb88af01', 6),
#  ('bca920774fcb', 6),
#  ('8640f20f0d73', 6),
#  ('5e8a2912e384', 6),
#  ('fe4c7ab44c2c', 6),
#  ('46377e32e0db', 6),
#  ('4ae735cf1627', 6),
#  ('3ad8a0d46735', 6),
#  ('3a52d0952d47', 6),
#  ('8c8ef25a196c', 5),
#  ('94652d8acdeb', 5),
#  ('5e9f5858aff8', 5),
#  ('4c32759896b5', 5),
#  ('4a8024956528', 5),
#  ('daa11979355a', 5),
#  ('8685b65b418b', 5),
#  ('daeabc6e65d0', 5),
#  ('daf71ca699d3', 5),
#  ('0a53957c696f', 5),
#  ('82125c64fa4e', 5),
#  ('daa119a16829', 5),
#  ('daa1190b65ec', 5),
#  ('daa11968602b', 5),
#  ('daa119c0499d', 5),
#  ('664ff1b22abd', 5),
#  ('b2ebb68965be', 5),
#  ('000027000000', 5),
#  ('daa119bf80f6', 5),
#  ('e2518a2bc757', 5),
#  ('be5d5fcf082c', 5),
#  ('daa119073f01', 5),
#  ('7264cd8ac165', 5),
#  ('8256ab065b5c', 5),
#  ('d65319eef22f', 5),
#  ('9800c6f11427', 5),
#  ('c4b301d0cd69', 5),
#  ('daa11995fb90', 5),
#  ('aa84c8ed4bc4', 5),
#  ('9ce33f6630b4', 5),
#  ('8c8ef256f22a', 5),
#  ('1ad5c501cf4b', 5),
#  ('daa119f6bd86', 5),
#  ('e0a3ac55d8bd', 5),
#  ('b4bff622f089', 5),
#  ('e2c63b320c59', 5),
#  ('aa59fe1924c5', 5),
#  ('daa1199105bd', 5),
#  ('16f62e8ba988', 5),
#  ('7214508f28aa', 5),
#  ('beb2201c8ea2', 5),
#  ('a63a369042b7', 5),
#  ('6e24854f8771', 5),
#  ('9a4224607f9b', 5),
#  ('cacf286913f7', 5),
#  ('daa119828b21', 5),
#  ('d4970bc0e87e', 5),
#  ('c23bd6420a09', 5),
#  ('807abf3af14a', 5),
#  ('a0cc2bcb73bd', 5),
#  ('3408bcdfee91', 5),
#  ('6edd0e075a65', 5),
#  ('060740000b00', 5),
#  ('16113477860f', 5),
#  ('128ca908b8d2', 5),
#  ('825f9d252ed4', 5),
#  ('daa11915d6d4', 4),
#  ('6245e7e61223', 4),
#  ('daa119e669bb', 4),
#  ('ca654daf47e1', 4),
#  ('c69e9e84e7c0', 4),
#  ('daa1199330e4', 4),
#  ('daa119183a10', 4),
#  ('daa119756bb8', 4),
#  ('94652dca21b2', 4),
#  ('daa119fd5971', 4),
#  ('42d293a7448f', 4),
#  ('5433cbb86f18', 4),
#  ('9e9d7c2614f0', 4),
#  ('8e6769dd0383', 4),
#  ('daa1193fd38e', 4),
#  ('36aada5a90fb', 4),
#  ('020fc3000100', 4),
#  ('24f0945e4694', 4),
#  ('f6037fff1f7f', 4),
#  ('de420c564069', 4),
#  ('3a69f47083d0', 4),
#  ('daa119e5aae6', 4),
#  ('5ab458071fbd', 4),
#  ('fe19c9c715b2', 4),
#  ('070fc3000b00', 4),
#  ('8e7aa9746751', 4),
#  ('de16e1ae3eef', 4),
#  ('1abf2fa1fffc', 4),
#  ('4248e28fb581', 4),
#  ('74a34a9ebe5b', 4),
#  ('7a2c4cc27dbd', 4),
#  ('86cf53c9a2f2', 4),
#  ('98e79a5692fa', 4),
#  ('9801a7a005dd', 4),
#  ('7c0191231b90', 4),
#  ('bc543643d3d8', 4),
#  ('1e0352614ac9', 4),
#  ('36d5db6ce9da', 4),
#  ('9e881308507a', 4),
#  ('a45e60ba580b', 4),
#  ('de0a208af008', 4),
#  ('bef0c8a5a10b', 4),
#  ('daa11973f927', 4),
#  ('9ed289bd1403', 4),
#  ('38892c252ec1', 4),
#  ('1aaf51e2b5e2', 4),
#  ('ca2e44d7e32d', 4),
#  ('90187cf54f05', 4),
#  ('02ff44648ea3', 4),
#  ('daa119dbd78b', 4),
#  ('daa11992c1d1', 4),
#  ('e67db7731df2', 4),
#  ('62c1682ca260', 4),
#  ('de6f5c8ff78a', 4),
#  ('72c024050daf', 4),
#  ('d221e4fa0040', 4),
#  ('42e61666e602', 4),
#  ('cae2e111865a', 4),
#  ('7c50493fb48e', 4),
#  ('daa1197d4219', 4),
#  ('380fc3000b00', 4),
#  ('da1a049906b7', 4),
#  ('5e80ce048260', 4),
#  ('96c617a36eb5', 4),
#  ('661e2fa50cd3', 4),
#  ('f0dce2dc89de', 4),
#  ('daa1190fbb5e', 3),
#  ('8e74a437cb47', 3),
#  ('daa1198a5a7e', 3),
#  ('b285b16a0cbb', 3),
#  ('daa11925797d', 3),
#  ('5a4213f7f1f8', 3),
#  ('daa119d38c39', 3),
#  ('daa11973c2e0', 3),
#  ('f2b76bc366a0', 3),
#  ('90b0ed3d2073', 3),
#  ('daa119b74859', 3),
#  ('0056cd5b87d2', 3),
#  ('daa119196da1', 3),
#  ('e251e47c4f28', 3),
#  ('be52523c78b3', 3),
#  ('dee8205ea961', 3),
#  ('90187c78e097', 3),
#  ('daa1195f40f4', 3),
#  ('9af44de30c87', 3),
#  ('727a55788992', 3),
#  ('52e6583169a6', 3),
#  ('6021011fc4a9', 3),
#  ('f288451909e8', 3),
#  ('f265166e2528', 3),
#  ('daa1196c9f49', 3),
#  ('3a17d10dd4e7', 3),
#  ('daa1199390aa', 3),
#  ('9e77159371df', 3),
#  ('1c7b2159a0e3', 3),
#  ('beeb00ec387e', 3),
#  ('ca506c4a7b72', 3),
#  ('fc4203cfcb1a', 3),
#  ('9cb2b22b79e2', 3),
#  ('d2f569cfcbba', 3),
#  ('d2b1db5ee92a', 3),
#  ('320bc02164b9', 3),
#  ('eaf6e17af2cd', 3),
#  ('daa119f0bfce', 3),
#  ('daa11950c221', 3),
#  ('f4f5dbc86f2f', 3),
#  ('a2f7b1e83d03', 3),
#  ('daa119144f45', 3),
#  ('2a9aec14e638', 3),
#  ('f67417d4fa48', 3),
#  ('daa119d497b0', 3),
#  ('3a70906d5d2a', 3),
#  ('d63d6cd67619', 3),
#  ('feeb6c73ded8', 3),
#  ('26965902388f', 3),
#  ('ee7d1106010c', 3),
#  ('026f49a37cf6', 3),
#  ('daa119d8f73d', 3),
#  ('bc8385e07021', 3),
#  ('8aeb3c64d706', 3),
#  ('5e3763b9a626', 3),
#  ('f20508cec0c4', 3),
#  ('daa119412f72', 2),
#  ('e8b2ace47a3b', 2),
#  ('4622cda168c1', 2),
#  ('00eebd4273c3', 2),
#  ('daa11975d83e', 2),
#  ('98ca336ba0ff', 2),
#  ('c2a1653162e2', 2),
#  ('4ad439c63af3', 2),
#  ('32b741193cdb', 2),
#  ('0251539379f9', 2),
#  ('46fc1f86aac3', 2),
#  ('cc088df094ae', 2),
#  ('fa98b6ea7f97', 2),
#  ('ac0d1bf1c90a', 2),
#  ('120fc3000b00', 2),
#  ('ee28348d0119', 2),
#  ('f6bd4675812c', 2)]

# %%
sp4_filtered = [s for s in sp4 if s["mac"] == '98e79a51579c']
sp5_filtered = [s for s in sp5 if s["mac"] == '98e79a51579c']
sp6_filtered = [s for s in sp6 if s["mac"] == '98e79a51579c']

# %%
def add_sniff_plot(in_list,x_offset,y_offset):
    plt.scatter([s["time"]+x_offset for s in in_list],[y_offset]*len(in_list),c=[int(s["mac"][-2:],16)/256 for s in in_list])

# %%
plt.close()
add_sniff_plot(sp4_filtered,0,0)
add_sniff_plot(sp5_filtered,20.52,1)
add_sniff_plot(sp6_filtered,29.1,2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
